# %% [markdown]
# A PyTorch flavor of the code at From https://towardsdatascience.com/auto-encoder-what-is-it-and-what-is-it-used-for-part-1-3e5c6f017726/ and
# https://gist.github.com/wmlba/ed6448da9dce3a3c0f6ee78e972dd07b#file-autoencoder_feedforward-py.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DL4DS/sp2025_homeworks/blob/main/lecture_collateral/vae/02_autoencoder_cifar10.ipynb)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import random
import os

# %%
# Create data directory if it doesn't exist
os.makedirs('./data', exist_ok=True)

# %%
# Define the Autoencoder architecture
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(32*32*3, 1024),
            nn.ELU(),
            nn.Linear(1024, 256),
            nn.ELU(),
            nn.Linear(256, 64),  # bottleneck
        )
        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(64, 256),
            nn.ELU(),
            nn.Linear(256, 1024),
            nn.ELU(),
            nn.Linear(1024, 32*32*3),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

    def encode(self, x):
        return self.encoder(x)

    def decode(self, z):
        return self.decoder(z)

# %%
# Set device
device = torch.device('mps' if torch.backends.mps.is_available() else 'cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Load CIFAR10 dataset
transform = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = datasets.CIFAR10('./data', train=True, download=True, transform=transform)
test_dataset = datasets.CIFAR10('./data', train=False, transform=transform)

print(f"Training dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")

train_loader = DataLoader(train_dataset, batch_size=1024, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1024, shuffle=False)
# Out:
# Using device: mps
# Training dataset size: 50000
# Test dataset size: 10000

# %%
# Training loop
def train(model, optimizer, criterion, epochs):
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for batch_idx, (data, _) in enumerate(train_loader):
            data = data.view(data.size(0), -1).to(device)
            
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, data)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            
        print(f'Epoch: {epoch+1}, Average Loss: {train_loss / len(train_loader):.4f}')

# %%
# Get encoded representations and reconstructions
def get_representations(loader, model):
    model.eval()
    encoded_data = []
    decoded_data = []
    original_data = []
    with torch.no_grad():
        for data, _ in loader:
            data = data.view(data.size(0), -1).to(device)
            encoded = model.encode(data)
            decoded = model.decode(encoded)
            encoded_data.append(encoded)
            decoded_data.append(decoded)
            original_data.append(data)
    return torch.cat(encoded_data), torch.cat(decoded_data), torch.cat(original_data)

# %%
def visualize_results(original, reconstructed, n=10):
    try:
        # If we're given single images, convert them to batch format
        if len(original.shape) == 1:
            original = original.unsqueeze(0)
        if len(reconstructed.shape) == 1:
            reconstructed = reconstructed.unsqueeze(0)
        
        # Randomly select n indices if we have more than n samples
        if original.shape[0] > n:
            indices = random.sample(range(original.shape[0]), n)
        else:
            indices = range(original.shape[0])
            n = len(indices)
        
        plt.figure(figsize=(20, 4))
        for i, idx in enumerate(indices):
            # Original
            ax = plt.subplot(2, n, i + 1)
            plt.imshow(original[idx].detach().cpu().reshape(3, 32, 32).permute(1, 2, 0).numpy())
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            
            # Reconstructed
            ax = plt.subplot(2, n, i + 1 + n)
            plt.imshow(reconstructed[idx].detach().cpu().reshape(3, 32, 32).permute(1, 2, 0).numpy())
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
        plt.show()
    except Exception as e:
        print(f"Error in visualization: {str(e)}")
        print(f"Original shape: {original.shape}")
        print(f"Reconstructed shape: {reconstructed.shape}")

# %% [markdown]
# If you want to train again from scratch then rerun starting with the next
# model initialization cell.

# %%
# Initialize model, loss function and optimizer
model = Autoencoder().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters())

# %% [markdown]
# You can run the following cell repeatedly to continue training the model.

# %%
# Train the model
print("Training the model...")
train(model, optimizer, criterion, epochs=50)
print("Training completed!")
# Out:
# Training the model...
# Epoch: 1, Average Loss: 0.0390
# Epoch: 2, Average Loss: 0.0271
# Epoch: 3, Average Loss: 0.0249
# Epoch: 4, Average Loss: 0.0227
# Epoch: 5, Average Loss: 0.0211
# Epoch: 6, Average Loss: 0.0200
# Epoch: 7, Average Loss: 0.0187
# Epoch: 8, Average Loss: 0.0176
# Epoch: 9, Average Loss: 0.0183
# Epoch: 10, Average Loss: 0.0167
# Epoch: 11, Average Loss: 0.0164
# Epoch: 12, Average Loss: 0.0159
# Epoch: 13, Average Loss: 0.0158
# Epoch: 14, Average Loss: 0.0144
# Epoch: 15, Average Loss: 0.0144
# Epoch: 16, Average Loss: 0.0145
# Epoch: 17, Average Loss: 0.0141
# Epoch: 18, Average Loss: 0.0140
# Epoch: 19, Average Loss: 0.0130
# Epoch: 20, Average Loss: 0.0130
# Epoch: 21, Average Loss: 0.0129
# Epoch: 22, Average Loss: 0.0136
# Epoch: 23, Average Loss: 0.0514
# Epoch: 24, Average Loss: 0.0220
# Epoch: 25, Average Loss: 0.0174
# Epoch: 26, Average Loss: 0.0158
# Epoch: 27, Average Loss: 0.0147
# Epoch: 28, Average Loss: 0.0141
# Epoch: 29, Average Loss: 0.0135
# Epoch: 30, Average Loss: 0.0133
# Epoch: 31, Average Loss: 0.0130
# Epoch: 32, Average Loss: 0.0128
# Epoch: 33, Average Loss: 0.0126
# Epoch: 34, Average Loss: 0.0125
# Epoch: 35, Average Loss: 0.0124
# Epoch: 36, Average Loss: 0.0123
# Epoch: 37, Average Loss: 0.0121
# Epoch: 38, Average Loss: 0.0120
# Epoch: 39, Average Loss: 0.0119
# Epoch: 40, Average Loss: 0.0118
# Epoch: 41, Average Loss: 0.0117
# Epoch: 42, Average Loss: 0.0116
# Epoch: 43, Average Loss: 0.0115
# Epoch: 44, Average Loss: 0.0115
# Epoch: 45, Average Loss: 0.0113
# Epoch: 46, Average Loss: 0.0114
# Epoch: 47, Average Loss: 0.0114
# Epoch: 48, Average Loss: 0.0113
# Epoch: 49, Average Loss: 0.0113
# Epoch: 50, Average Loss: 0.0111
# Training completed!

# %%
# Get encoded and decoded data
print("Getting representations...")
encoded_data, decoded_output, original_data = get_representations(train_loader, model)
print(f"Encoded data shape: {encoded_data.shape}")
print(f"Decoded output shape: {decoded_output.shape}")
print(f"Original data shape: {original_data.shape}")
# Out:
# Getting representations...
# Encoded data shape: torch.Size([50000, 64])
# Decoded output shape: torch.Size([50000, 3072])
# Original data shape: torch.Size([50000, 3072])

# %%
# Example usage for multiple images
indices = random.sample(range(len(train_dataset)), 10)
original_imgs = torch.stack([train_dataset[idx][0].view(-1) for idx in indices])
decoded_imgs = model(original_imgs.to(device)).cpu()

# Visualize multiple image comparisons
visualize_results(original_imgs, decoded_imgs, n=8)
